# %%
import pandas as pd

# %%
data_withdate = pd.read_csv('총데이터/일별_전체데이터.csv', encoding='cp949')
data_withdate
# Out:
#             date  TPM2.5  TPM10  JPM2.5  JPM10  BPM2.5  BPM10     교통량합계  \
# 0     2017-06-01      40     67      72    164      23     57  108656.0
# 1     2017-06-02      14     52      44    132      23     65  114477.0
# 2     2017-06-03      30     54      28     79      29     56  111557.0
# 3     2017-06-04      35     70      48    114      48     93   57121.0
# 4     2017-06-05      52     97      23     63      65    115  112199.0
# ...          ...     ...    ...     ...    ...     ...    ...       ...
# 1486  2021-06-26      32     61      26     44      22     40   91068.0
# 1487  2021-06-27      37     70      38     66      26     48   76373.0
# 1488  2021-06-28      43     77      43     75      32     53   97692.0
# 1489  2021-06-29      27     46      22     40      26     40   96636.0
# 1490  2021-06-30      27     44      24     46      14     27   97579.0
#
#       평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  \
# 0         22.0       0.0         1.8      0.001          42.0     0.024
# 1         20.6       0.0         1.5      0.002          34.0     0.030
# 2         20.6       0.0         1.8      0.003          25.0     0.032
# 3         21.2       0.0         1.4      0.003          31.0     0.040
# 4         22.6       0.0         1.3      0.004          35.0     0.033
# ...        ...       ...         ...        ...           ...       ...
# 1486      22.7      11.5         0.9      0.003          19.0     0.036
# 1487      24.9       0.0         0.9      0.003          22.0     0.040
# 1488      25.1       0.0         1.2      0.003          24.0     0.038
# 1489      23.7       0.0         1.0      0.003          25.0     0.037
# 1490      24.6       9.0         0.9      0.003          38.0     0.034
#
#       NO2 (ppm)  CO (ppm)  PM2.5 (ug/m3)
# 0         0.023       0.5           24.0
# 1         0.023       0.6           14.0
# 2         0.021       0.5           11.0
# 3         0.020       0.5           14.0
# 4         0.031       0.7           14.0
# ...         ...       ...            ...
# 1486      0.018       0.4           10.0
# 1487      0.014       0.4           13.0
# 1488      0.018       0.4           15.0
# 1489      0.019       0.4           16.0
# 1490      0.024       0.4           23.0
#
# [1491 rows x 17 columns]

# %%
data = data_withdate.set_axis(['date', 'TPM2.5', 'TPM10', 'JPM2.5', 'JPM10', 'BPM2.5', 'BPM10', 
                                   '교통량합계', '평균기온', '일강수량', '평균풍속', 
                                   'SO2', 'PM10', 'O3', 'NO2', 'CO', 'PM2.5'], axis=1)

data
# Out:
#             date  TPM2.5  TPM10  JPM2.5  JPM10  BPM2.5  BPM10     교통량합계  평균기온  \
# 0     2017-06-01      40     67      72    164      23     57  108656.0  22.0
# 1     2017-06-02      14     52      44    132      23     65  114477.0  20.6
# 2     2017-06-03      30     54      28     79      29     56  111557.0  20.6
# 3     2017-06-04      35     70      48    114      48     93   57121.0  21.2
# 4     2017-06-05      52     97      23     63      65    115  112199.0  22.6
# ...          ...     ...    ...     ...    ...     ...    ...       ...   ...
# 1486  2021-06-26      32     61      26     44      22     40   91068.0  22.7
# 1487  2021-06-27      37     70      38     66      26     48   76373.0  24.9
# 1488  2021-06-28      43     77      43     75      32     53   97692.0  25.1
# 1489  2021-06-29      27     46      22     40      26     40   96636.0  23.7
# 1490  2021-06-30      27     44      24     46      14     27   97579.0  24.6
#
#       일강수량  평균풍속    SO2  PM10     O3    NO2   CO  PM2.5
# 0      0.0   1.8  0.001  42.0  0.024  0.023  0.5   24.0
# 1      0.0   1.5  0.002  34.0  0.030  0.023  0.6   14.0
# 2      0.0   1.8  0.003  25.0  0.032  0.021  0.5   11.0
# 3      0.0   1.4  0.003  31.0  0.040  0.020  0.5   14.0
# 4      0.0   1.3  0.004  35.0  0.033  0.031  0.7   14.0
# ...    ...   ...    ...   ...    ...    ...  ...    ...
# 1486  11.5   0.9  0.003  19.0  0.036  0.018  0.4   10.0
# 1487   0.0   0.9  0.003  22.0  0.040  0.014  0.4   13.0
# 1488   0.0   1.2  0.003  24.0  0.038  0.018  0.4   15.0
# 1489   0.0   1.0  0.003  25.0  0.037  0.019  0.4   16.0
# 1490   9.0   0.9  0.003  38.0  0.034  0.024  0.4   23.0
#
# [1491 rows x 17 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

fig, ax = plt.subplots(figsize=(11,4))

# %%
sns.scatterplot(data=data, x='date', y= 'PM10', ax=ax, marker='.', label='Daily')
sns.lineplot(data=data, x='date', y= 'PM10', ax=ax, label='Daily2')

#ax.xaxis.set_major_locator(mdates.YearLocator()) # doesn't work
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('Air')
ax.set_title('Air ')
# Out:
# Text(0.5, 1.0, 'Air ')

# %% [markdown]
# ## 다시

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from datetime import datetime

from pandas import Series
# %matplotlib inline
import warnings

warnings.filterwarnings("ignore")

import statsmodels.api as sm

# %%
data = pd.read_csv('총데이터/일별_대기질.csv')

data
# Out:
#             date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0     2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1     2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2     2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3     2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4     2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...          ...        ...           ...       ...        ...       ...
# 1486  2021-06-26      0.003          19.0     0.036      0.018       0.4
# 1487  2021-06-27      0.003          22.0     0.040      0.014       0.4
# 1488  2021-06-28      0.003          24.0     0.038      0.018       0.4
# 1489  2021-06-29      0.003          25.0     0.037      0.019       0.4
# 1490  2021-06-30      0.003          38.0     0.034      0.024       0.4
#
#       PM2.5 (ug/m3)
# 0              24.0
# 1              14.0
# 2              11.0
# 3              14.0
# 4              14.0
# ...             ...
# 1486           10.0
# 1487           13.0
# 1488           15.0
# 1489           16.0
# 1490           23.0
#
# [1491 rows x 7 columns]

# %%
data_10 = data.drop(columns=['SO2 (ppm)', 'PM2.5 (ug/m3)', 'CO (ppm)',
                            'NO2 (ppm)', 'O3 (ppm)'])

data_10
# Out:
#             date  PM10 (ug/m3)
# 0     2017-06-01          42.0
# 1     2017-06-02          34.0
# 2     2017-06-03          25.0
# 3     2017-06-04          31.0
# 4     2017-06-05          35.0
# ...          ...           ...
# 1486  2021-06-26          19.0
# 1487  2021-06-27          22.0
# 1488  2021-06-28          24.0
# 1489  2021-06-29          25.0
# 1490  2021-06-30          38.0
#
# [1491 rows x 2 columns]

# %%
data_10.date = pd.to_datetime(data_10.date, format = '%Y-%m-%d')

data_10
# Out:
#            date  PM10 (ug/m3)
# 0    2017-06-01          42.0
# 1    2017-06-02          34.0
# 2    2017-06-03          25.0
# 3    2017-06-04          31.0
# 4    2017-06-05          35.0
# ...         ...           ...
# 1486 2021-06-26          19.0
# 1487 2021-06-27          22.0
# 1488 2021-06-28          24.0
# 1489 2021-06-29          25.0
# 1490 2021-06-30          38.0
#
# [1491 rows x 2 columns]

# %%
data_10['year'] = data_10.date.dt.year
data_10['month'] = data_10.date.dt.month
data_10['day'] = data_10.date.dt.day

data_10
# Out:
#            date  PM10 (ug/m3)  year  month  day
# 0    2017-06-01          42.0  2017      6    1
# 1    2017-06-02          34.0  2017      6    2
# 2    2017-06-03          25.0  2017      6    3
# 3    2017-06-04          31.0  2017      6    4
# 4    2017-06-05          35.0  2017      6    5
# ...         ...           ...   ...    ...  ...
# 1486 2021-06-26          19.0  2021      6   26
# 1487 2021-06-27          22.0  2021      6   27
# 1488 2021-06-28          24.0  2021      6   28
# 1489 2021-06-29          25.0  2021      6   29
# 1490 2021-06-30          38.0  2021      6   30
#
# [1491 rows x 5 columns]

# %%
data_10.rename(columns = {'PM10 (ug/m3)':'PM10'}, inplace = True)

# %%
newdf = data_10

# %%
newdf.groupby('month').PM10.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
newdf.groupby('year').PM10.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
newdf.set_index('date', inplace=True)

newdf
# Out:
#             PM10  year  month  day
# date
# 2017-06-01  42.0  2017      6    1
# 2017-06-02  34.0  2017      6    2
# 2017-06-03  25.0  2017      6    3
# 2017-06-04  31.0  2017      6    4
# 2017-06-05  35.0  2017      6    5
# ...          ...   ...    ...  ...
# 2021-06-26  19.0  2021      6   26
# 2021-06-27  22.0  2021      6   27
# 2021-06-28  24.0  2021      6   28
# 2021-06-29  25.0  2021      6   29
# 2021-06-30  38.0  2021      6   30
#
# [1491 rows x 4 columns]

# %%
monthly = newdf.resample('M').sum()

monthly
# Out:
#               PM10   year  month  day
# date
# 2017-06-30  1272.0  60510    180  465
# 2017-07-31   794.0  62527    217  496
# 2017-08-31   847.0  62527    248  496
# 2017-09-30  1355.0  60510    270  465
# 2017-10-31  1400.0  62527    310  496
# 2017-11-30  2035.0  60510    330  465
# 2017-12-31  1811.0  62527    372  496
# 2018-01-31  1953.0  62558     31  496
# 2018-02-28  1735.0  56504     56  406
# 2018-03-31  1717.0  62558     93  496
# 2018-04-30  1678.0  60540    120  465
# 2018-05-31  1485.0  62558    155  496
# 2018-06-30  1248.0  60540    180  465
# 2018-07-31   717.0  62558    217  496
# 2018-08-31   732.0  62558    248  496
# 2018-09-30   808.0  60540    270  465
# 2018-10-31  1250.0  62558    310  496
# 2018-11-30  2347.0  60540    330  465
# 2018-12-31  2252.0  62558    372  496
# 2019-01-31  2602.0  62589     31  496
# 2019-02-28  2155.0  56532     56  406
# 2019-03-31  2440.0  62589     93  496
# 2019-04-30  1521.0  60570    120  465
# 2019-05-31  1563.0  62589    155  496
# 2019-06-30   969.0  60570    180  465
# 2019-07-31   703.0  62589    217  496
# 2019-08-31   803.0  62589    248  496
# 2019-09-30   608.0  60570    270  465
# 2019-10-31   764.0  62589    310  496
# 2019-11-30  1468.0  60570    330  465
# 2019-12-31  1576.0  62589    372  496
# 2020-01-31  1592.0  62620     31  496
# 2020-02-29  1343.0  58580     58  435
# 2020-03-31  1335.0  62620     93  496
# 2020-04-30  1240.0  60600    120  465
# 2020-05-31   875.0  62620    155  496
# 2020-06-30   929.0  60600    180  465
# 2020-07-31   457.0  62620    217  496
# 2020-08-31   560.0  62620    248  496
# 2020-09-30   661.0  60600    270  465
# 2020-10-31  1062.0  62620    310  496
# 2020-11-30  1288.0  60600    330  465
# 2020-12-31  1410.0  62620    372  496
# 2021-01-31  1450.0  62651     31  496
# 2021-02-28  1426.0  56588     56  406
# 2021-03-31  2128.0  62651     93  496
# 2021-04-30  1295.0  60630    120  465
# 2021-05-31  1678.0  62651    155  496
# 2021-06-30   964.0  60630    180  465

# %%
from statsmodels.tsa.stattools import adfuller

def df_test(time_series):
    
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(time_series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value',
                                            '#Lags Used', 
                                             'Number of Observations Used'])
    
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' %key] = value
        
    print(dfoutput)

# %%
df_test(monthly.PM10)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.532362
# p-value                         0.000172
# #Lags Used                      2.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# Critical Value (5%)            -2.926785
# Critical Value (10%)           -2.601541
# dtype: float64

# %%
first_diff = monthly.PM10.diff()[1:]

print(list(first_diff))
# Out:
# [-478.0, 53.0, 508.0, 45.0, 635.0, -224.0, 142.0, -218.0, -18.0, -39.0, -193.0, -237.0, -531.0, 15.0, 76.0, 442.0, 1097.0, -95.0, 350.0, -447.0, 285.0, -919.0, 42.0, -594.0, -266.0, 100.0, -195.0, 156.0, 704.0, 108.0, 16.0, -249.0, -8.0, -95.0, -365.0, 54.0, -472.0, 103.0, 101.0, 401.0, 226.0, 122.0, 40.0, -24.0, 702.0, -833.0, 383.0, -714.0]

# %%
df_test(first_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.647052
# p-value                         0.000106
# #Lags Used                      8.000000
# Number of Observations Used    39.000000
# Critical Value (1%)            -3.610400
# Critical Value (5%)            -2.939109
# Critical Value (10%)           -2.608063
# dtype: float64

# %%
import statsmodels.api as sm
sm.tsa.seasonal_decompose(monthly.PM10).plot()
plt.show()

# %%
monthly.PM10
# Out:
# date
# 2017-06-30    1272.0
# 2017-07-31     794.0
# 2017-08-31     847.0
# 2017-09-30    1355.0
# 2017-10-31    1400.0
# 2017-11-30    2035.0
# 2017-12-31    1811.0
# 2018-01-31    1953.0
# 2018-02-28    1735.0
# 2018-03-31    1717.0
# 2018-04-30    1678.0
# 2018-05-31    1485.0
# 2018-06-30    1248.0
# 2018-07-31     717.0
# 2018-08-31     732.0
# 2018-09-30     808.0
# 2018-10-31    1250.0
# 2018-11-30    2347.0
# 2018-12-31    2252.0
# 2019-01-31    2602.0
# 2019-02-28    2155.0
# 2019-03-31    2440.0
# 2019-04-30    1521.0
# 2019-05-31    1563.0
# 2019-06-30     969.0
# 2019-07-31     703.0
# 2019-08-31     803.0
# 2019-09-30     608.0
# 2019-10-31     764.0
# 2019-11-30    1468.0
# 2019-12-31    1576.0
# 2020-01-31    1592.0
# 2020-02-29    1343.0
# 2020-03-31    1335.0
# 2020-04-30    1240.0
# 2020-05-31     875.0
# 2020-06-30     929.0
# 2020-07-31     457.0
# 2020-08-31     560.0
# 2020-09-30     661.0
# 2020-10-31    1062.0
# 2020-11-30    1288.0
# 2020-12-31    1410.0
# 2021-01-31    1450.0
# 2021-02-28    1426.0
# 2021-03-31    2128.0
# 2021-04-30    1295.0
# 2021-05-31    1678.0
# 2021-06-30     964.0
# Freq: M, Name: PM10, dtype: float64

# %% [markdown]
# import statsmodels.api as sm
# sm.tsa.seasonal_decompose(newdf.PM10).plot()
# plt.show()

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

acf_plot = plot_acf(first_diff)

# %%
pacf_plot = plot_pacf(first_diff)

# %%
from datetime import timedelta

train_end = datetime(2020,6,30)
test_end = datetime(2021,6,30)

train_data = monthly[:train_end]
test_data = monthly[train_end + timedelta(days=1):test_end]

# %%
train_data.tail(5)
# Out:
#               PM10   year  month  day
# date
# 2020-02-29  1343.0  58580     58  435
# 2020-03-31  1335.0  62620     93  496
# 2020-04-30  1240.0  60600    120  465
# 2020-05-31   875.0  62620    155  496
# 2020-06-30   929.0  60600    180  465

# %%
test_data.tail(5)
# Out:
#               PM10   year  month  day
# date
# 2021-02-28  1426.0  56588     56  406
# 2021-03-31  2128.0  62651     93  496
# 2021-04-30  1295.0  60630    120  465
# 2021-05-31  1678.0  62651    155  496
# 2021-06-30   964.0  60630    180  465

# %%
from pmdarima import auto_arima

# pmdarima.arima.ndiffs() # finding the best d and D

# %%
from statsmodels.tsa.api import ExponentialSmoothing

air = ExponentialSmoothing(np.asarray(train_data['PM10']),
                                  seasonal_periods=12, trend='add',
                                  seasonal='add')

air_fit = air.fit()

air_forecast = air_fit.forecast(len(test_data))

plt.figure(figsize=(16,8))

plt.plot(train_data.index, train_data['PM10'], "b.-", label='Train Data')
plt.plot(test_data.index, test_data['PM10'], "ro-", label='Original Test Data')
plt.plot(test_data.index, air_forecast, "gx-", label='Air Forecast Data')
plt.ylabel('PM10', fontsize=16)
plt.xlabel('date', fontsize=16)
plt.legend(loc='best')
plt.title('Air Forecast', fontsize=10)
plt.show()

# %% [markdown]
# ### Sarima

# %%
Sarimax_model = auto_arima(train_data.PM10,
                          start_p=0,
                          start_q=0,
                          max_p=3,
                          max_q=3,
                          m=12,
                          test='adf',
                          seasonal=True,
                          d=1,
                          D=1,
                          trace=True,
                          error_action='ignore',
                          suppress_warnings=True,
                          stepwise=True)

Sarimax_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=356.499, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=347.024, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=353.159, Time=0.04 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=inf, Time=0.64 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.39 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.74 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=348.509, Time=0.03 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=348.642, Time=0.11 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=348.228, Time=0.17 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=347.407, Time=0.07 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=350.214, Time=0.25 sec
#  ARIMA(1,1,0)(1,1,0)[12] intercept   : AIC=348.913, Time=0.22 sec
#
# Best model:  ARIMA(1,1,0)(1,1,0)[12]
# Total fit time: 3.256 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   37
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -170.512
# Date:                            Thu, 12 Aug 2021   AIC                            347.024
# Time:                                    16:43:32   BIC                            350.558
# Sample:                                         0   HQIC                           347.962
#                                              - 37
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4007      0.228     -1.754      0.079      -0.849       0.047
# ar.S.L12      -0.7188      0.122     -5.912      0.000      -0.957      -0.481
# sigma2      5.897e+04   1.76e+04      3.357      0.001    2.45e+04    9.34e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.59
# Prob(Q):                              0.93   Prob(JB):                         0.75
# Heteroskedasticity (H):               0.51   Skew:                            -0.38
# Prob(H) (two-sided):                  0.36   Kurtosis:                         2.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

my_order = (1,1,0)

my_seasonal_order = (1, 1, 0, 12)

# define model
model = SARIMAX(train_data.PM10, order=my_order, seasonal_order=
                my_seasonal_order)

# %%
# fit the model
model_fit = model.fit()

# %%
# get the predictions and residuals
predictions = model_fit.forecast(len(test_data.PM10))
predictions = pd.Series(predictions, index=test_data.index)
residuals = test_data.PM10 - predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
# air_fit = air.fit()
# air_forecast = air_fit.forecast(len(test_data))

plt.figure(figsize=(16,8))

plt.plot(train_data.index, train_data['PM10'], "b.-", label='Train Data')
plt.plot(test_data.index, test_data['PM10'], "ro-", label='Original Test Data')
plt.plot(test_data.index, predictions, "gx-", label='SARIMA Forecast Data')
plt.ylabel('PM10', fontsize=16)
plt.xlabel('date', fontsize=16)
plt.legend(loc='best')
plt.title('Air SARIMA Forecast', fontsize=10)
plt.show()

# %%
residuals.mean()
# Out:
# 83.8314355434715

# %%
predictions
# Out:
# date
# 2020-07-31     315.678739
# 2020-08-31     417.421131
# 2020-09-30     392.043893
# 2020-10-31     763.722393
# 2020-11-30    1746.182101
# 2020-12-31    1709.878331
# 2021-01-31    1965.320883
# 2021-02-28    1574.251170
# 2021-03-31    1776.766395
# 2021-04-30    1089.485810
# 2021-05-31    1017.036061
# 2021-06-30     605.235864
# Freq: M, Name: predicted_mean, dtype: float64

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(residuals/test_data.PM10)),3))
# Out:
# Mean Absolute Percent Error: 0.281

# %%
from sklearn.metrics import mean_squared_error, r2_score

# 평가 지표 계산
mse = mean_squared_error(test_data['PM10'], predictions)
rmse = np.sqrt(mse)

r2 = r2_score(test_data['PM10'], predictions)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse, rmse))
print("R2: {:3f}".format(r2))
# Out:
# MSE: 126682.115, RMSE: 355.924
# R2: 0.413279

# %%
# 평가 지표 계산
mse2 = mean_squared_error(test_data['PM10'], air_forecast)
rmse2 = np.sqrt(mse2)

r22 = r2_score(test_data['PM10'], air_forecast)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse2, rmse2))
print("R2: {:3f}".format(r22))
# Out:
# MSE: 114806.367, RMSE: 338.831
# R2: 0.468281
