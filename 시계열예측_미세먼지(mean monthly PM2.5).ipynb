# %%
import pandas as pd

# %%
data_withdate = pd.read_csv('총데이터/일별_전체데이터.csv', encoding='cp949')
data_withdate
# Out:
#             date  TPM2.5  TPM10  JPM2.5  JPM10  BPM2.5  BPM10     교통량합계  \
# 0     2017-06-01      40     67      72    164      23     57  108656.0
# 1     2017-06-02      14     52      44    132      23     65  114477.0
# 2     2017-06-03      30     54      28     79      29     56  111557.0
# 3     2017-06-04      35     70      48    114      48     93   57121.0
# 4     2017-06-05      52     97      23     63      65    115  112199.0
# ...          ...     ...    ...     ...    ...     ...    ...       ...
# 1486  2021-06-26      32     61      26     44      22     40   91068.0
# 1487  2021-06-27      37     70      38     66      26     48   76373.0
# 1488  2021-06-28      43     77      43     75      32     53   97692.0
# 1489  2021-06-29      27     46      22     40      26     40   96636.0
# 1490  2021-06-30      27     44      24     46      14     27   97579.0
#
#       평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  \
# ...

# %%
data = data_withdate.set_axis(['date', 'TPM2.5', 'TPM10', 'JPM2.5', 'JPM10', 'BPM2.5', 'BPM10', 
                                   '교통량합계', '평균기온', '일강수량', '평균풍속', 
                                   'SO2', 'PM10', 'O3', 'NO2', 'CO', 'PM2.5'], axis=1)

data
# Out:
#             date  TPM2.5  TPM10  JPM2.5  JPM10  BPM2.5  BPM10     교통량합계  평균기온  \
# 0     2017-06-01      40     67      72    164      23     57  108656.0  22.0
# 1     2017-06-02      14     52      44    132      23     65  114477.0  20.6
# 2     2017-06-03      30     54      28     79      29     56  111557.0  20.6
# 3     2017-06-04      35     70      48    114      48     93   57121.0  21.2
# 4     2017-06-05      52     97      23     63      65    115  112199.0  22.6
# ...          ...     ...    ...     ...    ...     ...    ...       ...   ...
# 1486  2021-06-26      32     61      26     44      22     40   91068.0  22.7
# 1487  2021-06-27      37     70      38     66      26     48   76373.0  24.9
# 1488  2021-06-28      43     77      43     75      32     53   97692.0  25.1
# 1489  2021-06-29      27     46      22     40      26     40   96636.0  23.7
# 1490  2021-06-30      27     44      24     46      14     27   97579.0  24.6
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

fig, ax = plt.subplots(figsize=(11,4))

# %%
sns.scatterplot(data=data, x='date', y= 'PM10', ax=ax, marker='.', label='Daily')
sns.lineplot(data=data, x='date', y= 'PM10', ax=ax, label='Daily2')

#ax.xaxis.set_major_locator(mdates.YearLocator()) # doesn't work
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('Air')
ax.set_title('Air ')
# Out:
# Text(0.5, 1.0, 'Air ')

# %% [markdown]
# ## 다시

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from datetime import datetime

from pandas import Series
# %matplotlib inline
import warnings

warnings.filterwarnings("ignore")

import statsmodels.api as sm

# %%
data = pd.read_csv('총데이터/일별_대기질.csv')

data
# Out:
#             date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0     2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1     2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2     2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3     2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4     2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...          ...        ...           ...       ...        ...       ...
# 1486  2021-06-26      0.003          19.0     0.036      0.018       0.4
# 1487  2021-06-27      0.003          22.0     0.040      0.014       0.4
# 1488  2021-06-28      0.003          24.0     0.038      0.018       0.4
# 1489  2021-06-29      0.003          25.0     0.037      0.019       0.4
# 1490  2021-06-30      0.003          38.0     0.034      0.024       0.4
#
#       PM2.5 (ug/m3)
# 0              24.0
# 1              14.0
# 2              11.0
# ...

# %%
data_10 = data.drop(columns=['SO2 (ppm)', 'PM10 (ug/m3)', 'CO (ppm)',
                            'NO2 (ppm)', 'O3 (ppm)'])

data_10
# Out:
#             date  PM2.5 (ug/m3)
# 0     2017-06-01           24.0
# 1     2017-06-02           14.0
# 2     2017-06-03           11.0
# 3     2017-06-04           14.0
# 4     2017-06-05           14.0
# ...          ...            ...
# 1486  2021-06-26           10.0
# 1487  2021-06-27           13.0
# 1488  2021-06-28           15.0
# 1489  2021-06-29           16.0
# 1490  2021-06-30           23.0
#
# [1491 rows x 2 columns]

# %%
data_10['PM2.5 (ug/m3)'].idxmin()
# Out:
# 843

# %%
data_10.iloc[1445]
# Out:
# date             2021-05-16
# PM2.5 (ug/m3)           4.0
# Name: 1445, dtype: object

# %%
data_10['PM2.5 (ug/m3)'].idxmax()
# Out:
# 638

# %%
data_10.iloc[1437]
# Out:
# date             2021-05-08
# PM2.5 (ug/m3)          99.0
# Name: 1437, dtype: object

# %%
data_10['PM2.5 (ug/m3)'].mean()
# Out:
# 21.089872568745808

# %%
data_10.date = pd.to_datetime(data_10.date, format = '%Y-%m-%d')

data_10
# Out:
#            date  PM2.5 (ug/m3)
# 0    2017-06-01           24.0
# 1    2017-06-02           14.0
# 2    2017-06-03           11.0
# 3    2017-06-04           14.0
# 4    2017-06-05           14.0
# ...         ...            ...
# 1486 2021-06-26           10.0
# 1487 2021-06-27           13.0
# 1488 2021-06-28           15.0
# 1489 2021-06-29           16.0
# 1490 2021-06-30           23.0
#
# [1491 rows x 2 columns]

# %%
data_10['year'] = data_10.date.dt.year
data_10['month'] = data_10.date.dt.month
data_10['day'] = data_10.date.dt.day

data_10
# Out:
#            date  PM2.5 (ug/m3)  year  month  day
# 0    2017-06-01           24.0  2017      6    1
# 1    2017-06-02           14.0  2017      6    2
# 2    2017-06-03           11.0  2017      6    3
# 3    2017-06-04           14.0  2017      6    4
# 4    2017-06-05           14.0  2017      6    5
# ...         ...            ...   ...    ...  ...
# 1486 2021-06-26           10.0  2021      6   26
# 1487 2021-06-27           13.0  2021      6   27
# 1488 2021-06-28           15.0  2021      6   28
# 1489 2021-06-29           16.0  2021      6   29
# 1490 2021-06-30           23.0  2021      6   30
#
# [1491 rows x 5 columns]

# %%
data_10.rename(columns = {'PM2.5 (ug/m3)':'PM25'}, inplace = True)

# %%
newdf = data_10

newdf
# Out:
#             PM25  year  month  day
# date
# 2017-06-01  24.0  2017      6    1
# 2017-06-02  14.0  2017      6    2
# 2017-06-03  11.0  2017      6    3
# 2017-06-04  14.0  2017      6    4
# 2017-06-05  14.0  2017      6    5
# ...          ...   ...    ...  ...
# 2021-06-26  10.0  2021      6   26
# 2021-06-27  13.0  2021      6   27
# 2021-06-28  15.0  2021      6   28
# 2021-06-29  16.0  2021      6   29
# 2021-06-30  23.0  2021      6   30
#
# [1491 rows x 4 columns]

# %%
newdf.groupby('month').PM25.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
newdf.groupby('year').PM25.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
newdf.set_index('date', inplace=True)

newdf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-bd4dd916181f> in <module>
# ----> 1 newdf.set_index('date', inplace=True)
#       2
#       3 newdf
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
monthly = newdf.resample('M').mean()

monthly
# Out:
#                  PM25    year  month   day
# date
# 2017-06-30  23.366667  2017.0    6.0  15.5
# 2017-07-31  19.129032  2017.0    7.0  16.0
# 2017-08-31  11.935484  2017.0    8.0  16.0
# 2017-09-30  19.133333  2017.0    9.0  15.5
# 2017-10-31  15.064516  2017.0   10.0  16.0
# 2017-11-30  23.333333  2017.0   11.0  15.5
# 2017-12-31  26.548387  2017.0   12.0  16.0
# 2018-01-31  31.225806  2018.0    1.0  16.0
# 2018-02-28  27.178571  2018.0    2.0  14.5
# 2018-03-31  27.677419  2018.0    3.0  16.0
# 2018-04-30  22.133333  2018.0    4.0  15.5
# 2018-05-31  20.645161  2018.0    5.0  16.0
# 2018-06-30  22.600000  2018.0    6.0  15.5
# 2018-07-31  12.935484  2018.0    7.0  16.0
# 2018-08-31  10.032258  2018.0    8.0  16.0
# 2018-09-30   9.400000  2018.0    9.0  15.5
# 2018-10-31  13.838710  2018.0   10.0  16.0
# 2018-11-30  36.000000  2018.0   11.0  15.5
# 2018-12-31  28.225806  2018.0   12.0  16.0
# 2019-01-31  38.967742  2019.0    1.0  16.0
# 2019-02-28  35.500000  2019.0    2.0  14.5
# ...

# %%
monthly['PM25'].idxmax()
# Out:
# Timestamp('2019-03-31 00:00:00', freq='M')

# %%
monthly.loc['2019-03-31']
# Out:
# PM25       40.516129
# year     2019.000000
# month       3.000000
# day        16.000000
# Name: 2019-03-31 00:00:00, dtype: float64

# %%
monthly['PM25'].idxmin()
# Out:
# Timestamp('2018-09-30 00:00:00', freq='M')

# %%
monthly.loc['2018-09-30']
# Out:
# PM25        9.4
# year     2018.0
# month       9.0
# day        15.5
# Name: 2018-09-30 00:00:00, dtype: float64

# %%
monthly['PM25'].mean()
# Out:
# 21.122552106811256

# %%
from statsmodels.tsa.stattools import adfuller

def df_test(time_series):
    
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(time_series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value',
                                            '#Lags Used', 
                                             'Number of Observations Used'])
    
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' %key] = value
        
    print(dfoutput)

# %%
df_test(monthly.PM25)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.097424
# p-value                         0.000978
# #Lags Used                      2.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# Critical Value (5%)            -2.926785
# Critical Value (10%)           -2.601541
# dtype: float64

# %%
first_diff = monthly.PM25.diff()[1:]

print(list(first_diff))
# Out:
# [-4.237634408602151, -7.193548387096774, 7.197849462365591, -4.068817204301075, 8.268817204301074, 3.21505376344086, 4.677419354838712, -4.047235023041477, 0.49884792626728114, -5.544086021505375, -1.4881720430107528, 1.9548387096774213, -9.66451612903226, -2.903225806451612, -0.6322580645161295, 4.438709677419354, 22.161290322580648, -7.774193548387096, 10.741935483870968, -3.467741935483872, 5.016129032258064, -22.149462365591397, 5.536559139784945, -4.236559139784944, -3.537634408602152, 2.225806451612904, -5.921505376344086, 1.5021505376344084, 7.39784946236559, 4.698924731182796, 2.0, -2.8253615127919893, -4.529477196885431, -2.7440860215053746, 2.7440860215053746, 1.8225806451612918, -9.080645161290322, 0.09677419354838612, -3.4494623655913976, 5.1591397849462375, 5.140860215053763, 2.375268817204301, -1.0645161290322598, 1.8582949308755765, -0.2131336405529929, -9.455913978494625, 4.230107526881721, 0.5032258064516135]

# %%
df_test(first_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.620057
# p-value                         0.000119
# #Lags Used                     10.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64

# %%
import statsmodels.api as sm
sm.tsa.seasonal_decompose(monthly.PM25).plot()
plt.show()

# %%
monthly.PM25
# Out:
# date
# 2017-06-30    23.366667
# 2017-07-31    19.129032
# 2017-08-31    11.935484
# 2017-09-30    19.133333
# 2017-10-31    15.064516
# 2017-11-30    23.333333
# 2017-12-31    26.548387
# 2018-01-31    31.225806
# 2018-02-28    27.178571
# 2018-03-31    27.677419
# 2018-04-30    22.133333
# 2018-05-31    20.645161
# 2018-06-30    22.600000
# 2018-07-31    12.935484
# 2018-08-31    10.032258
# 2018-09-30     9.400000
# 2018-10-31    13.838710
# 2018-11-30    36.000000
# 2018-12-31    28.225806
# 2019-01-31    38.967742
# 2019-02-28    35.500000
# 2019-03-31    40.516129
# 2019-04-30    18.366667
# 2019-05-31    23.903226
# 2019-06-30    19.666667
# 2019-07-31    16.129032
# 2019-08-31    18.354839
# 2019-09-30    12.433333
# 2019-10-31    13.935484
# 2019-11-30    21.333333
# 2019-12-31    26.032258
# 2020-01-31    28.032258
# 2020-02-29    25.206897
# 2020-03-31    20.677419
# 2020-04-30    17.933333
# 2020-05-31    20.677419
# 2020-06-30    22.500000
# 2020-07-31    13.419355
# ...

# %% [markdown]
# import statsmodels.api as sm
# sm.tsa.seasonal_decompose(newdf.PM10).plot()
# plt.show()

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

acf_plot = plot_acf(first_diff)

# %%
pacf_plot = plot_pacf(first_diff)

# %%
from datetime import timedelta

train_end = datetime(2020,5,31)
test_end = datetime(2021,6,30)

train_data = monthly[:train_end]
test_data = monthly[train_end + timedelta(days=1):test_end]

# %%
test_data.tail(5)
# Out:
#                  PM25    year  month   day
# date
# 2021-02-28  23.535714  2021.0    2.0  14.5
# 2021-03-31  23.322581  2021.0    3.0  16.0
# 2021-04-30  13.866667  2021.0    4.0  15.5
# 2021-05-31  18.096774  2021.0    5.0  16.0
# 2021-06-30  18.600000  2021.0    6.0  15.5

# %%
from pmdarima import auto_arima

# pmdarima.arima.ndiffs() # finding the best d and D

# %%
from statsmodels.tsa.api import ExponentialSmoothing

air = ExponentialSmoothing(np.asarray(train_data['PM25']),
                                  seasonal_periods=12, trend='add',
                                  seasonal='add')

air_fit = air.fit()

air_forecast = air_fit.forecast(len(test_data))

plt.figure(figsize=(16,8))

plt.plot(train_data.index, train_data['PM25'], "b.-", label='Train Data')
plt.plot(test_data.index, test_data['PM25'], "ro-", label='Original Test Data')
plt.plot(test_data.index, air_forecast, "gx-", label='Air Forecast Data')
plt.ylabel('PM2.5', fontsize=16)
plt.xlabel('date', fontsize=16)
plt.legend(loc='best')
plt.title('PM2.5 Air Forecast', fontsize=10)
plt.show()

# %% [markdown]
# ### Sarima

# %%
Sarimax_model = auto_arima(train_data.PM25,
                          start_p=0,
                          start_q=0,
                          max_p=3,
                          max_q=3,
                          m=12,
                          test='adf',
                          seasonal=True,
                          d=1,
                          D=1,
                          trace=True,
                          error_action='ignore',
                          suppress_warnings=True,
                          stepwise=True)

Sarimax_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=161.374, Time=0.13 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=169.305, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=153.002, Time=0.04 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=164.802, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=inf, Time=0.38 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=154.979, Time=0.27 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=156.973, Time=0.47 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=159.373, Time=0.04 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=153.897, Time=0.08 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=152.421, Time=0.06 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=166.125, Time=0.04 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=154.262, Time=0.54 sec
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

my_order = (0,1,1)

my_seasonal_order = (1, 1, 0, 12)

# define model
model = SARIMAX(train_data.PM25, order=my_order, seasonal_order=
                my_seasonal_order)

# %%
# fit the model
model_fit = model.fit()

# %%
# get the predictions and residuals
predictions = model_fit.forecast(len(test_data.PM25))
predictions = pd.Series(predictions, index=test_data.index)
residuals = test_data.PM25 - predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model PM2.5', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
# air_fit = air.fit()
# air_forecast = air_fit.forecast(len(test_data))

plt.figure(figsize=(16,8))

plt.plot(train_data.index, train_data['PM25'], "b.-", label='Train Data')
plt.plot(test_data.index, test_data['PM25'], "ro-", label='Original Test Data')
plt.plot(test_data.index, predictions, "gx-", label='SARIMA Forecast Data')
plt.ylabel('PM2.5', fontsize=16)
plt.xlabel('date', fontsize=16)
plt.legend(loc='best')
plt.title('PM2.5 Air SARIMA Forecast', fontsize=10)
plt.show()

# %%
residuals.mean()
# Out:
# -2.102041006294221

# %%
predictions
# Out:
# date
# 2020-06-30    19.205403
# 2020-07-31    10.324555
# 2020-08-31     8.077366
# 2020-09-30     6.768579
# 2020-10-31    10.831683
# 2020-11-30    31.104632
# 2020-12-31    24.925832
# 2021-01-31    34.549617
# 2021-02-28    31.164040
# 2021-03-31    34.959223
# 2021-04-30    15.291836
# 2021-05-31    20.471219
# 2021-06-30    16.588263
# Freq: M, Name: predicted_mean, dtype: float64

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(residuals/test_data.PM25)),3))
# Out:
# Mean Absolute Percent Error: 0.291

# %%
from sklearn.metrics import mean_squared_error, r2_score

# 평가 지표 계산
mse = mean_squared_error(test_data['PM25'], predictions)
rmse = np.sqrt(mse)

r2 = r2_score(test_data['PM25'], predictions)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse, rmse))
print("R2: {:3f}".format(r2))
# Out:
# MSE: 43.945, RMSE: 6.629
# R2: -1.291123

# %%
# 평가 지표 계산
mse2 = mean_squared_error(test_data['PM25'], air_forecast)
rmse2 = np.sqrt(mse2)

r22 = r2_score(test_data['PM25'], air_forecast)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse2, rmse2))
print("R2: {:3f}".format(r22))
# Out:
# MSE: 12.360, RMSE: 3.516
# R2: 0.355617
