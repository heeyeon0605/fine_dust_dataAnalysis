# %%
import pandas as pd

# %%
data_air = pd.read_csv('총데이터/일별_대기질.csv')
data_air
# Out:
#             date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0     2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1     2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2     2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3     2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4     2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...          ...        ...           ...       ...        ...       ...
# 1486  2021-06-26      0.003          19.0     0.036      0.018       0.4
# 1487  2021-06-27      0.003          22.0     0.040      0.014       0.4
# 1488  2021-06-28      0.003          24.0     0.038      0.018       0.4
# 1489  2021-06-29      0.003          25.0     0.037      0.019       0.4
# 1490  2021-06-30      0.003          38.0     0.034      0.024       0.4
#
#       PM2.5 (ug/m3)
# 0              24.0
# 1              14.0
# 2              11.0
# ...

# %%
data_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491 entries, 0 to 1490
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1491 non-null   object
#  1   SO2 (ppm)      1480 non-null   float64
#  2   PM10 (ug/m3)   1491 non-null   float64
#  3   O3 (ppm)       1475 non-null   float64
#  4   NO2 (ppm)      1476 non-null   float64
#  5   CO (ppm)       1480 non-null   float64
#  6   PM2.5 (ug/m3)  1491 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 81.7+ KB

# %%
air.date = pd.to_datetime(air.date, format = '%Y-%m-%d')

# %%
air.columns
# Out:
# Index(['date', 'SO2 (ppm)', 'PM10 (ug/m3)', 'O3 (ppm)', 'NO2 (ppm)',
#        'CO (ppm)', 'PM2.5 (ug/m3)'],
#       dtype='object')

# %%
air.describe()
# Out:
#          SO2 (ppm)  PM10 (ug/m3)     O3 (ppm)    NO2 (ppm)     CO (ppm)  \
# count  1480.000000   1491.000000  1475.000000  1476.000000  1480.000000
# mean      0.003308     44.467471     0.020851     0.026883     0.408311
# std       0.001322     28.726051     0.012553     0.011986     0.180053
# min       0.001000      2.000000     0.001000     0.004000     0.100000
# 25%       0.003000     26.000000     0.011000     0.017000     0.300000
# 50%       0.003000     39.000000     0.019000     0.024500     0.400000
# 75%       0.004000     57.000000     0.029000     0.034000     0.500000
# max       0.009000    428.000000     0.116000     0.072000     1.300000
#
#        PM2.5 (ug/m3)
# count    1491.000000
# mean       21.089873
# std        12.989618
# min         1.000000
# 25%        12.000000
# 50%        18.000000
# 75%        27.000000
# max       121.000000

# %%
air[:1400]
# Out:
#            date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0    2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1    2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2    2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3    2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4    2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...         ...        ...           ...       ...        ...       ...
# 1395 2021-03-27      0.003          44.0     0.020      0.033       0.4
# 1396 2021-03-28      0.002          15.0     0.033      0.017       0.4
# 1397 2021-03-29      0.003         409.0     0.030      0.019       0.4
# 1398 2021-03-30      0.004         152.0     0.023      0.027       0.4
# 1399 2021-03-31      0.003          51.0     0.019      0.036       0.4
#
#       PM2.5 (ug/m3)
# 0              24.0
# 1              14.0
# 2              11.0
# ...

# %%
air[:1396].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data_weather = pd.read_csv('기상데이터/일별_문화동기상.csv', encoding = 'cp949')
data_weather
# Out:
#               일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)
# 0     2017-06-01      22.0       0.0         1.8
# 1     2017-06-02      20.6       0.0         1.5
# 2     2017-06-03      20.6       0.0         1.8
# 3     2017-06-04      21.2       0.0         1.4
# 4     2017-06-05      22.6       0.0         1.3
# ...          ...       ...       ...         ...
# 1486  2021-06-26      22.7      11.5         0.9
# 1487  2021-06-27      24.9       0.0         0.9
# 1488  2021-06-28      25.1       0.0         1.2
# 1489  2021-06-29      23.7       0.0         1.0
# 1490  2021-06-30      24.6       9.0         0.9
#
# [1491 rows x 4 columns]

# %%
data_weather[data_weather['일시'] == '2020-10-19']
# Out:
#               일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)
# 1236  2020-10-19      13.2       0.0         0.7

# %%
data_weather.dropna(inplace = True)

# %%
data_weather.일시 = pd.to_datetime(data_weather.일시, format = '%Y-%m-%d')

# %%
data_weather
# Out:
#              일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)
# 0    2017-06-01      22.0       0.0         1.8
# 1    2017-06-02      20.6       0.0         1.5
# 2    2017-06-03      20.6       0.0         1.8
# 3    2017-06-04      21.2       0.0         1.4
# 4    2017-06-05      22.6       0.0         1.3
# ...         ...       ...       ...         ...
# 1486 2021-06-26      22.7      11.5         0.9
# 1487 2021-06-27      24.9       0.0         0.9
# 1488 2021-06-28      25.1       0.0         1.2
# 1489 2021-06-29      23.7       0.0         1.0
# 1490 2021-06-30      24.6       9.0         0.9
#
# [1491 rows x 4 columns]

# %%
hap = pd.concat([data_air,data_weather], axis=1)
hap.drop(columns = '일시', inplace = True)

# %%
hap
# Out:
#             date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0     2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1     2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2     2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3     2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4     2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...          ...        ...           ...       ...        ...       ...
# 1486  2021-06-26      0.003          19.0     0.036      0.018       0.4
# 1487  2021-06-27      0.003          22.0     0.040      0.014       0.4
# 1488  2021-06-28      0.003          24.0     0.038      0.018       0.4
# 1489  2021-06-29      0.003          25.0     0.037      0.019       0.4
# 1490  2021-06-30      0.003          38.0     0.034      0.024       0.4
#
#       PM2.5 (ug/m3)  avg_temp  rain  wind_speed
# ...

# %%
hap.columns = ['date', 'SO2 (ppm)', 'PM10 (ug/m3)', 'O3 (ppm)', 'NO2 (ppm)',
       'CO (ppm)', 'PM2.5 (ug/m3)', 'avg_temp', 'rain', 'wind_speed']

# %%
import matplotlib.pyplot as plt

# %%
hap.plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)', 'avg_temp', 'rain', 'wind_speed'])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
hap1 = hap[:1000].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[:1000].plot(x = 'date', y = ['avg_temp'], secondary_y=True, ax = hap1)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#import matplotlib.pyplot as plt

hap1 = hap[:1000].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[:1000].plot(x = 'date', y = ['rain'], secondary_y=True, ax = hap1)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[540:630].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[540:630].plot(x = 'date', y = ['avg_temp'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[540:630].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[540:630].plot(x = 'date', y = ['rain'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[1000:1100].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[1000:1100].plot(x = 'date', y = ['avg_temp'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[1000:1100].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[1000:1100].plot(x = 'date', y = ['rain'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[820:910].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[820:910].plot(x = 'date', y = ['avg_temp'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[820:910].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[820:910].plot(x = 'date', y = ['rain'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[730:820].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[730:820].plot(x = 'date', y = ['avg_temp'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[730:820].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[730:820].plot(x = 'date', y = ['rain'], secondary_y=True, ax = hap1)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hap1 = hap[550:700].plot(x = 'date', y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = hap[550:700].plot(x = 'date', y = ['avg_temp'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#hap['quarter'] = hap.date.apply(lambda x: pd.Timestamp(x).quarter)
hap['year'] = hap.date.apply(lambda x: x.strftime('%Y'))
hap
# Out:
#            date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0    2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1    2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2    2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3    2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4    2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...         ...        ...           ...       ...        ...       ...
# 1486 2021-06-26      0.003          19.0     0.036      0.018       0.4
# 1487 2021-06-27      0.003          22.0     0.040      0.014       0.4
# 1488 2021-06-28      0.003          24.0     0.038      0.018       0.4
# 1489 2021-06-29      0.003          25.0     0.037      0.019       0.4
# 1490 2021-06-30      0.003          38.0     0.034      0.024       0.4
#
#       PM2.5 (ug/m3)  avg_temp  rain  wind_speed  quarter  year
# ...

# %%
first
# Out:
#            date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 214  2018-01-01      0.005          57.0     0.010      0.037       0.8
# 215  2018-01-02      0.006          75.0     0.005      0.047       1.1
# 216  2018-01-03      0.006          45.0     0.014      0.034       0.5
# 217  2018-01-04      0.005          60.0     0.009      0.041       0.5
# 218  2018-01-05      0.005          68.0     0.007      0.052       0.6
# ...         ...        ...           ...       ...        ...       ...
# 1395 2021-03-27      0.003          44.0     0.020      0.033       0.4
# 1396 2021-03-28      0.002          15.0     0.033      0.017       0.4
# 1397 2021-03-29      0.003         409.0     0.030      0.019       0.4
# 1398 2021-03-30      0.004         152.0     0.023      0.027       0.4
# 1399 2021-03-31      0.003          51.0     0.019      0.036       0.4
#
#       PM2.5 (ug/m3)  avg_temp  rain  wind_speed  quarter  year
# ...

# %%
traffic = pd.read_csv('대전교통량.csv', header = [0, 1], index_col = [0, 1, 2])
#traffic.drop(columns = 'Unnamed: 0', inplace = True)
traffic
# Out:
#                      0:00               1:00               2:00              \
#                      통행속도 차로당교통량  총교통량  통행속도 차로당교통량  총교통량  통행속도 차로당교통량 총교통량
# 0   2017년06월  계룡로    59.6    455  1609  62.0    306  1090  62.7    236  843
# 1   2017년06월  계백로    60.5    268   929  61.3    174   607  61.3    126  442
# 2   2017년06월  계족로    50.1    197   686  49.9    123   426  49.6     95  329
# 3   2017년06월  동서대로2  62.4     69   276  64.2     48   192  64.7     41  162
# 4   2017년07월  계룡로    69.6    425  1498  70.7    300  1060  70.6    233  829
# ...                   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 151 2021년 07월 동서대로2  63.4    114   454  63.5     73   294  63.5     57  230
# 152 2021년 08월 계룡로    63.3    188   681  61.8    129   467  62.1     98  359
# 153 2021년 08월 계백로    60.0    124   347  59.9     78   220  61.1     60  166
# 154 2021년 08월 계족로    71.1     71   246  69.4     52   178  71.4     41  141
# ...

# %%
traffic.index
# Out:
# MultiIndex([(  0,  '2017년06월',   '계룡로'),
#             (  1,  '2017년06월',   '계백로'),
#             (  2,  '2017년06월',   '계족로'),
#             (  3,  '2017년06월', '동서대로2'),
#             (  4,  '2017년07월',   '계룡로'),
#             (  5,  '2017년07월',   '계백로'),
#             (  6,  '2017년07월',   '계족로'),
#             (  7,  '2017년07월', '동서대로2'),
#             (  8,  '2017년08월',   '계룡로'),
#             (  9,  '2017년08월',   '계백로'),
#             ...
#             (146, '2021년 06월',   '계족로'),
#             (147, '2021년 06월', '동서대로2'),
#             (148, '2021년 07월',   '계룡로'),
#             (149, '2021년 07월',   '계백로'),
#             (150, '2021년 07월',   '계족로'),
#             (151, '2021년 07월', '동서대로2'),
#             (152, '2021년 08월',   '계룡로'),
#             (153, '2021년 08월',   '계백로'),
#             (154, '2021년 08월',   '계족로'),
#             (155, '2021년 08월', '동서대로2')],
#            length=156)

# %%
traffic = pd.read_csv('대전교통량.csv', index_col = [0, 1, 2], header = [0, 1])
traffic
# Out:
#                     00:00:00              01:00:00              02:00:00  \
#                         통행속도 차로당교통량  총교통량     통행속도 차로당교통량  총교통량     통행속도
# 0   2017년06월  계룡로       59.6    455  1609     62.0    306  1090     62.7
# 1   2017년06월  계백로       60.5    268   929     61.3    174   607     61.3
# 2   2017년06월  계족로       50.1    197   686     49.9    123   426     49.6
# 3   2017년06월  동서대로2     62.4     69   276     64.2     48   192     64.7
# 4   2017년07월  계룡로       69.6    425  1498     70.7    300  1060     70.6
# ...                      ...    ...   ...      ...    ...   ...      ...
# 199 2021년 07월 동서대로2     63.4    114   454     63.5     73   294     63.5
# 200 2021년 08월 계룡로       63.3    188   681     61.8    129   467     62.1
# 201 2021년 08월 계백로       60.0    124   347     59.9     78   220     61.1
# 202 2021년 08월 계족로       71.1     71   246     69.4     52   178     71.4
# 203 2021년 08월 동서대로2     61.8     83   333     62.2     61   241     64.3
#
# ...

# %%
traffic.columns.set_names(['시간','분류'], inplace = True)
#traffic

# %%
traffic.index.set_names(['index', 'date', '도로'], inplace = True)
#traffic

# %%
total = traffic.xs('총교통량', axis = 1, level = 1)
daily = pd.DataFrame(total.sum(axis = 1))
daily
# Out:
#                            0
# index date      도로
# 0     2017년06월  계룡로    78842
# 1     2017년06월  계백로    54808
# 2     2017년06월  계족로    43061
# 3     2017년06월  동서대로2  28728
# 4     2017년07월  계룡로    75811
# ...                      ...
# 199   2021년 07월 동서대로2  38454
# 200   2021년 08월 계룡로    51499
# 201   2021년 08월 계백로    41884
# 202   2021년 08월 계족로    29106
# 203   2021년 08월 동서대로2  34692
#
# [204 rows x 1 columns]

# %%
daily.columns = ['교통량']
#daily

# %%
monthly = daily.reset_index().drop(columns = 'index')
monthly
# Out:
#           date     도로    교통량
# 0     2017년06월    계룡로  78842
# 1     2017년06월    계백로  54808
# 2     2017년06월    계족로  43061
# 3     2017년06월  동서대로2  28728
# 4     2017년07월    계룡로  75811
# ..         ...    ...    ...
# 199  2021년 07월  동서대로2  38454
# 200  2021년 08월    계룡로  51499
# 201  2021년 08월    계백로  41884
# 202  2021년 08월    계족로  29106
# 203  2021년 08월  동서대로2  34692
#
# [204 rows x 3 columns]

# %%
monthly_traffic = monthly.groupby('date', as_index = False).sum()
monthly_traffic[:-2]
# Out:
#          date     교통량
# 0    2017년06월  205439
# 1    2017년07월  199395
# 2    2017년08월  183046
# 3    2017년09월  187764
# 4    2017년10월  173061
# 5    2017년11월  182268
# 6    2017년12월  179561
# 7   2018년 01월  170077
# 8   2018년 02월  173990
# 9   2018년 03월  188181
# 10  2018년 04월  190461
# 11  2018년 05월  192838
# 12  2018년 06월  197070
# 13  2018년 07월  199446
# 14  2018년 08월  200403
# 15  2018년 09월  206146
# 16  2018년 10월  207016
# 17  2018년 11월  210276
# 18  2018년 12월  203061
# 19  2019년 01월  199012
# 20  2019년 02월  200627
# 21  2019년 03월  196126
# 22  2019년 04월  194135
# 23  2019년 05월  199488
# 24  2019년 06월  195527
# 25  2019년 07월  193392
# 26  2019년 08월  193055
# 27  2019년 09월  182070
# 28  2019년 10월  182254
# 29  2019년 11월  187412
# 30  2019년 12월  183252
# 31  2020년 01월  182847
# 32  2020년 02월  172058
# 33  2020년 03월  158858
# 34  2020년 04월  166150
# 35  2020년 05월  175069
# 36  2020년 06월  164912
# 37  2020년 07월  169658
# 38  2020년 08월  167388
# 39  2020년 09월  171573
# ...

# %%
lst = []
for i in monthly_traffic.교통량[:-2]:
    lst.append(i)
# Out:
# [205439,
#  199395,
#  183046,
#  187764,
#  173061,
#  182268,
#  179561,
#  170077,
#  173990,
#  188181,
#  190461,
#  192838,
#  197070,
#  199446,
#  200403,
#  206146,
#  207016,
#  210276,
#  203061,
#  199012,
#  200627,
#  196126,
#  194135,
#  199488,
#  195527,
#  193392,
#  193055,
#  182070,
#  182254,
#  187412,
#  183252,
#  182847,
#  172058,
#  158858,
#  166150,
#  175069,
#  164912,
#  169658,
#  167388,
#  171573,
#  173275,
#  174823,
#  164635,
#  153769,
#  168894,
#  176941,
#  179577,
#  170353,
#  171027]

# %%
monthly_hap['traffic'] = lst

# %%
monthly_hap.columns
# Out:
# Index(['SO2 (ppm)', 'PM10 (ug/m3)', 'O3 (ppm)', 'NO2 (ppm)', 'CO (ppm)',
#        'PM2.5 (ug/m3)', 'avg_temp', 'rain', 'wind_speed', 'quarter',
#        'traffic'],
#       dtype='object')

# %%
hap['month'] = hap.date.apply(lambda x: x.strftime('%m'))
monthly_hap = hap.groupby(['year', 'month']).mean()
monthly_hap
# Out:
#             SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# year month
# 2017 06      0.002567     42.400000  0.035033   0.028633  0.483333
#      07      0.002355     25.612903  0.018839   0.014677  0.287097
#      08      0.003000     27.322581  0.024250   0.017710  0.430000
#      09      0.002333     45.166667  0.021533   0.041233  0.450000
#      10      0.002839     45.161290  0.015194   0.038161  0.441935
#      11      0.003967     67.833333  0.012700   0.035533  0.603333
#      12      0.004742     58.419355  0.011032   0.039581  0.683871
# 2018 01      0.003710     63.000000  0.012613   0.040871  0.648387
#      02      0.005071     61.964286  0.017821   0.043714  0.589286
#      03      0.003419     55.387097  0.026097   0.029548  0.461290
#      04      0.002733     55.933333  0.031867   0.021033  0.383333
#      05      0.002833     47.903226  0.034867   0.017700  0.370000
#      06      0.002667     41.600000  0.034733   0.020000  0.363333
# ...

# %%
hap1 = monthly_hap.plot(y = ['PM2.5 (ug/m3)', 'PM10 (ug/m3)'])
hap2 = monthly_hap.plot(y = ['traffic'], secondary_y=True, ax = hap1)
#plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#import seaborn as sns

# 3행 4열의 subplots을 준비한다 (캔버스 작업)
fig, axs = plt.subplots(figsize = (8, 8), nrows = 2, ncols = 2)

x_features = ['avg_temp', 'rain', 'wind_speed', 'traffic']

for i, feature in enumerate(x_features):
    # 현재 subplot의 행, 열 번호 갱신
    row = int(i / 2) # column이 4개이므로
    col = i % 2
    # 산점도와 회귀선 시각화
    sns.regplot(x = feature, y = 'PM10 (ug/m3)', data = monthly_hap, ax = axs[row][col])

# %%
#from sklearn.model_selection import train_test_split

# X(독립변수), Y(종속변수) 분할
X = hap[['avg_temp', 'rain', 'wind_speed']]
y = hap['PM10 (ug/m3)']

# 학습용 데이터와 평가용 데이터로 분할하기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
#from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# 평가(검증) 데이터로 예측 수행 -> 예측 결과 y_pred구하기
y_pred = reg.predict(X_test)

# 평가 지표 계산
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse, rmse))
print("R2: {:3f}".format(r2))
# Out:
# MSE: 422.286, RMSE: 20.550
# R2: 0.273760

# %%
# ndarray의 실수를 부동 소수점으로 출력
np.set_printoptions(suppress = True)

# 회귀계수와 절편값 확인
print("Y 절편: {:.3f}".format(reg.intercept_))
print("회귀 계수: ", np.round(reg.coef_, 3))

# ndarray의 실수 출력 옵션 복구
np.set_printoptions(suppress = False)
# Out:
# Y 절편: 65.775
# 회귀 계수:  [-1.032 -0.442 -3.862]

# %%
#coef = pd.Series(data = np.round(reg.coef_, 3), index = X.columns)

#import matplotlib.pyplot as plt

plt.figure(figsize = (6, 6))
plt.ylim([0, 140])
plt.scatter(y_test, y_pred, s = 80)
plt.plot([0, 140], [0, 140], c = 'r', ls = '--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.grid()
plt.show()
