# %%
import pandas as pd

# %%
data_withdate = pd.read_csv('총데이터/일별_전체데이터.csv', encoding='cp949')
data_withdate
# Out:
#             date  TPM2.5  TPM10  JPM2.5  JPM10  BPM2.5  BPM10     교통량합계  \
# 0     2017-06-01      40     67      72    164      23     57  108656.0
# 1     2017-06-02      14     52      44    132      23     65  114477.0
# 2     2017-06-03      30     54      28     79      29     56  111557.0
# 3     2017-06-04      35     70      48    114      48     93   57121.0
# 4     2017-06-05      52     97      23     63      65    115  112199.0
# ...          ...     ...    ...     ...    ...     ...    ...       ...
# 1486  2021-06-26      32     61      26     44      22     40   91068.0
# 1487  2021-06-27      37     70      38     66      26     48   76373.0
# 1488  2021-06-28      43     77      43     75      32     53   97692.0
# 1489  2021-06-29      27     46      22     40      26     40   96636.0
# 1490  2021-06-30      27     44      24     46      14     27   97579.0
#
#       평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  \
# ...

# %%
data = data_withdate.set_axis(['date', 'TPM2.5', 'TPM10', 'JPM2.5', 'JPM10', 'BPM2.5', 'BPM10', 
                                   '교통량합계', '평균기온', '일강수량', '평균풍속', 
                                   'SO2', 'PM10', 'O3', 'NO2', 'CO', 'PM2.5'], axis=1)

data
# Out:
#             date  TPM2.5  TPM10  JPM2.5  JPM10  BPM2.5  BPM10     교통량합계  평균기온  \
# 0     2017-06-01      40     67      72    164      23     57  108656.0  22.0
# 1     2017-06-02      14     52      44    132      23     65  114477.0  20.6
# 2     2017-06-03      30     54      28     79      29     56  111557.0  20.6
# 3     2017-06-04      35     70      48    114      48     93   57121.0  21.2
# 4     2017-06-05      52     97      23     63      65    115  112199.0  22.6
# ...          ...     ...    ...     ...    ...     ...    ...       ...   ...
# 1486  2021-06-26      32     61      26     44      22     40   91068.0  22.7
# 1487  2021-06-27      37     70      38     66      26     48   76373.0  24.9
# 1488  2021-06-28      43     77      43     75      32     53   97692.0  25.1
# 1489  2021-06-29      27     46      22     40      26     40   96636.0  23.7
# 1490  2021-06-30      27     44      24     46      14     27   97579.0  24.6
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

fig, ax = plt.subplots(figsize=(11,4))

# %%
sns.scatterplot(data=data, x='date', y= 'PM10', ax=ax, marker='.', label='Daily')
sns.lineplot(data=data, x='date', y= 'PM10', ax=ax, label='Daily2')

#ax.xaxis.set_major_locator(mdates.YearLocator()) # doesn't work
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('Air')
ax.set_title('Air ')
# Out:
# Text(0.5, 1.0, 'Air ')

# %% [markdown]
# ## 다시

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from datetime import datetime

from pandas import Series
# %matplotlib inline
import warnings

warnings.filterwarnings("ignore")

import statsmodels.api as sm

# %%
data = pd.read_csv('총데이터/일별_대기질.csv')

data
# Out:
#             date  SO2 (ppm)  PM10 (ug/m3)  O3 (ppm)  NO2 (ppm)  CO (ppm)  \
# 0     2017-06-01      0.001          42.0     0.024      0.023       0.5
# 1     2017-06-02      0.002          34.0     0.030      0.023       0.6
# 2     2017-06-03      0.003          25.0     0.032      0.021       0.5
# 3     2017-06-04      0.003          31.0     0.040      0.020       0.5
# 4     2017-06-05      0.004          35.0     0.033      0.031       0.7
# ...          ...        ...           ...       ...        ...       ...
# 1486  2021-06-26      0.003          19.0     0.036      0.018       0.4
# 1487  2021-06-27      0.003          22.0     0.040      0.014       0.4
# 1488  2021-06-28      0.003          24.0     0.038      0.018       0.4
# 1489  2021-06-29      0.003          25.0     0.037      0.019       0.4
# 1490  2021-06-30      0.003          38.0     0.034      0.024       0.4
#
#       PM2.5 (ug/m3)
# 0              24.0
# 1              14.0
# 2              11.0
# ...

# %%
data_10 = data.drop(columns=['SO2 (ppm)', 'PM2.5 (ug/m3)', 'CO (ppm)',
                            'NO2 (ppm)', 'O3 (ppm)'])

data_10
# Out:
#             date  PM10 (ug/m3)
# 0     2017-06-01          42.0
# 1     2017-06-02          34.0
# 2     2017-06-03          25.0
# 3     2017-06-04          31.0
# 4     2017-06-05          35.0
# ...          ...           ...
# 1486  2021-06-26          19.0
# 1487  2021-06-27          22.0
# 1488  2021-06-28          24.0
# 1489  2021-06-29          25.0
# 1490  2021-06-30          38.0
#
# [1491 rows x 2 columns]

# %%
data_10['PM10 (ug/m3)'].idxmin()
# Out:
# 1445

# %%
data_10.iloc[1445]
# Out:
# date            2021-05-16
# PM10 (ug/m3)           2.0
# Name: 1445, dtype: object

# %%
data_10['PM10 (ug/m3)'].idxmax()
# Out:
# 1437

# %%
data_10.iloc[1437]
# Out:
# date            2021-05-08
# PM10 (ug/m3)         428.0
# Name: 1437, dtype: object

# %%
data_10['PM10 (ug/m3)'].mean()
# Out:
# 44.46747149564051

# %%
data_10.date = pd.to_datetime(data_10.date, format = '%Y-%m-%d')

data_10
# Out:
#            date  PM10 (ug/m3)
# 0    2017-06-01          42.0
# 1    2017-06-02          34.0
# 2    2017-06-03          25.0
# 3    2017-06-04          31.0
# 4    2017-06-05          35.0
# ...         ...           ...
# 1486 2021-06-26          19.0
# 1487 2021-06-27          22.0
# 1488 2021-06-28          24.0
# 1489 2021-06-29          25.0
# 1490 2021-06-30          38.0
#
# [1491 rows x 2 columns]

# %%
data_10['year'] = data_10.date.dt.year
data_10['month'] = data_10.date.dt.month
data_10['day'] = data_10.date.dt.day

data_10
# Out:
#            date  PM10 (ug/m3)  year  month  day
# 0    2017-06-01          42.0  2017      6    1
# 1    2017-06-02          34.0  2017      6    2
# 2    2017-06-03          25.0  2017      6    3
# 3    2017-06-04          31.0  2017      6    4
# 4    2017-06-05          35.0  2017      6    5
# ...         ...           ...   ...    ...  ...
# 1486 2021-06-26          19.0  2021      6   26
# 1487 2021-06-27          22.0  2021      6   27
# 1488 2021-06-28          24.0  2021      6   28
# 1489 2021-06-29          25.0  2021      6   29
# 1490 2021-06-30          38.0  2021      6   30
#
# [1491 rows x 5 columns]

# %%
data_10.rename(columns = {'PM10 (ug/m3)':'PM10'}, inplace = True)

# %%
newdf = data_10

# %%
newdf.groupby('month').PM10.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
newdf.groupby('year').PM10.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
newdf.set_index('date', inplace=True)

newdf
# Out:
#             PM10  year  month  day
# date
# 2017-06-01  42.0  2017      6    1
# 2017-06-02  34.0  2017      6    2
# 2017-06-03  25.0  2017      6    3
# 2017-06-04  31.0  2017      6    4
# 2017-06-05  35.0  2017      6    5
# ...          ...   ...    ...  ...
# 2021-06-26  19.0  2021      6   26
# 2021-06-27  22.0  2021      6   27
# 2021-06-28  24.0  2021      6   28
# 2021-06-29  25.0  2021      6   29
# 2021-06-30  38.0  2021      6   30
#
# [1491 rows x 4 columns]

# %%
monthly = newdf.resample('M').mean()

monthly
# Out:
#                  PM10    year  month   day
# date
# 2017-06-30  42.400000  2017.0    6.0  15.5
# 2017-07-31  25.612903  2017.0    7.0  16.0
# 2017-08-31  27.322581  2017.0    8.0  16.0
# 2017-09-30  45.166667  2017.0    9.0  15.5
# 2017-10-31  45.161290  2017.0   10.0  16.0
# 2017-11-30  67.833333  2017.0   11.0  15.5
# 2017-12-31  58.419355  2017.0   12.0  16.0
# 2018-01-31  63.000000  2018.0    1.0  16.0
# 2018-02-28  61.964286  2018.0    2.0  14.5
# 2018-03-31  55.387097  2018.0    3.0  16.0
# 2018-04-30  55.933333  2018.0    4.0  15.5
# 2018-05-31  47.903226  2018.0    5.0  16.0
# 2018-06-30  41.600000  2018.0    6.0  15.5
# 2018-07-31  23.129032  2018.0    7.0  16.0
# 2018-08-31  23.612903  2018.0    8.0  16.0
# 2018-09-30  26.933333  2018.0    9.0  15.5
# 2018-10-31  40.322581  2018.0   10.0  16.0
# 2018-11-30  78.233333  2018.0   11.0  15.5
# 2018-12-31  72.645161  2018.0   12.0  16.0
# 2019-01-31  83.935484  2019.0    1.0  16.0
# 2019-02-28  76.964286  2019.0    2.0  14.5
# ...

# %%
monthly['PM10'].idxmax()
# Out:
# Timestamp('2019-01-31 00:00:00', freq='M')

# %%
monthly.loc['2019-01-31']
# Out:
# PM10       83.935484
# year     2019.000000
# month       1.000000
# day        16.000000
# Name: 2019-01-31 00:00:00, dtype: float64

# %%
monthly['PM10'].mean()
# Out:
# 44.55961736990998

# %%
from statsmodels.tsa.stattools import adfuller

def df_test(time_series):
    
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(time_series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value',
                                            '#Lags Used', 
                                             'Number of Observations Used'])
    
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' %key] = value
        
    print(dfoutput)

# %%
df_test(monthly.PM10)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.335152
# p-value                         0.000386
# #Lags Used                      2.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# Critical Value (5%)            -2.926785
# Critical Value (10%)           -2.601541
# dtype: float64

# %%
first_diff = monthly.PM10.diff()[1:]

print(list(first_diff))
# Out:
# [-16.787096774193547, 1.7096774193548399, 17.844086021505372, -0.005376344086016616, 22.67204301075268, -9.413978494623649, 4.58064516129032, -1.0357142857142847, -6.577188940092164, 0.5462365591397784, -8.030107526881714, -6.303225806451614, -18.470967741935485, 0.48387096774193594, 3.3204301075268816, 13.389247311827955, 37.910752688172046, -5.588172043010758, 11.290322580645167, -6.971198156682036, 1.7453917050691246, -28.00967741935483, -0.28064516129032313, -18.119354838709683, -9.622580645161289, 3.225806451612904, -5.636559139784946, 4.378494623655914, 24.28817204301075, 1.9053763440860223, 0.5161290322580641, -5.04449388209121, -3.24582869855395, -1.7311827956989205, -13.107526881720432, 2.740860215053761, -16.224731182795697, 3.322580645161292, 3.968817204301075, 12.224731182795697, 8.675268817204298, 2.550537634408606, 1.2903225806451601, 4.1543778801843345, 17.716589861751146, -25.478494623655912, 10.962365591397855, -21.995698924731187]

# %%
df_test(first_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.354226
# p-value                         0.000004
# #Lags Used                      7.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64

# %%
import statsmodels.api as sm
sm.tsa.seasonal_decompose(monthly.PM10).plot()
plt.show()

# %%
monthly.PM10
# Out:
# date
# 2017-06-30    42.400000
# 2017-07-31    25.612903
# 2017-08-31    27.322581
# 2017-09-30    45.166667
# 2017-10-31    45.161290
# 2017-11-30    67.833333
# 2017-12-31    58.419355
# 2018-01-31    63.000000
# 2018-02-28    61.964286
# 2018-03-31    55.387097
# 2018-04-30    55.933333
# 2018-05-31    47.903226
# 2018-06-30    41.600000
# 2018-07-31    23.129032
# 2018-08-31    23.612903
# 2018-09-30    26.933333
# 2018-10-31    40.322581
# 2018-11-30    78.233333
# 2018-12-31    72.645161
# 2019-01-31    83.935484
# 2019-02-28    76.964286
# 2019-03-31    78.709677
# 2019-04-30    50.700000
# 2019-05-31    50.419355
# 2019-06-30    32.300000
# 2019-07-31    22.677419
# 2019-08-31    25.903226
# 2019-09-30    20.266667
# 2019-10-31    24.645161
# 2019-11-30    48.933333
# 2019-12-31    50.838710
# 2020-01-31    51.354839
# 2020-02-29    46.310345
# 2020-03-31    43.064516
# 2020-04-30    41.333333
# 2020-05-31    28.225806
# 2020-06-30    30.966667
# 2020-07-31    14.741935
# ...

# %% [markdown]
# import statsmodels.api as sm
# sm.tsa.seasonal_decompose(newdf.PM10).plot()
# plt.show()

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

acf_plot = plot_acf(first_diff)

# %%
pacf_plot = plot_pacf(first_diff)

# %%
from datetime import timedelta

train_end = datetime(2020,6,31)
test_end = datetime(2021,6,30)

train_data = monthly[:train_end]
test_data = monthly[train_end + timedelta(days=1):test_end]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-ce9a193372cb> in <module>
#       1 from datetime import timedelta
#       2
# ----> 3 train_end = datetime(2020,6,31)
#       4 test_end = datetime(2021,6,30)
#       5
#
# ValueError: day is out of range for month

# %%
test_data.tail(5)

# %%
from pmdarima import auto_arima

# pmdarima.arima.ndiffs() # finding the best d and D

# %%
from statsmodels.tsa.api import ExponentialSmoothing

air = ExponentialSmoothing(np.asarray(train_data['PM10']),
                                  seasonal_periods=12, trend='add',
                                  seasonal='add')

air_fit = air.fit()

air_forecast = air_fit.forecast(len(test_data))

plt.figure(figsize=(16,8))

plt.plot(train_data.index, train_data['PM10'], "b.-", label='Train Data')
plt.plot(test_data.index, test_data['PM10'], "ro-", label='Original Test Data')
plt.plot(test_data.index, air_forecast, "gx-", label='Air Forecast Data')
plt.ylabel('PM10', fontsize=16)
plt.xlabel('date', fontsize=16)
plt.legend(loc='best')
plt.title('Air Forecast', fontsize=10)
plt.show()

# %% [markdown]
# ### Sarima

# %%
Sarimax_model = auto_arima(train_data.PM10,
                          start_p=0,
                          start_q=0,
                          max_p=3,
                          max_q=3,
                          m=12,
                          test='adf',
                          seasonal=True,
                          d=1,
                          D=1,
                          trace=True,
                          error_action='ignore',
                          suppress_warnings=True,
                          stepwise=True)

Sarimax_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=176.838, Time=0.10 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=181.458, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=174.781, Time=0.04 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=180.662, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=inf, Time=0.40 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.20 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.49 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=174.838, Time=0.02 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=176.760, Time=0.06 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=176.475, Time=0.08 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=174.708, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=181.382, Time=0.03 sec
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

my_order = (0,1,1)

my_seasonal_order = (1, 1, 0, 12)

# define model
model = SARIMAX(train_data.PM10, order=my_order, seasonal_order=
                my_seasonal_order)

# %%
# fit the model
model_fit = model.fit()

# %%
# get the predictions and residuals
predictions = model_fit.forecast(len(test_data.PM10))
predictions = pd.Series(predictions, index=test_data.index)
residuals = test_data.PM10 - predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
# air_fit = air.fit()
# air_forecast = air_fit.forecast(len(test_data))

plt.figure(figsize=(16,8))

plt.plot(train_data.index, train_data['PM10'], "b.-", label='Train Data')
plt.plot(test_data.index, test_data['PM10'], "ro-", label='Original Test Data')
plt.plot(test_data.index, predictions, "gx-", label='SARIMA Forecast Data')
plt.ylabel('PM10', fontsize=16)
plt.xlabel('date', fontsize=16)
plt.legend(loc='best')
plt.title('Air SARIMA Forecast', fontsize=10)
plt.show()

# %%
residuals.mean()
# Out:
# 9.582357425397472

# %%
predictions
# Out:
# date
# 2020-06-30    20.598766
# 2020-07-31     4.449279
# 2020-08-31     5.652530
# 2020-09-30     6.622986
# 2020-10-31    17.648154
# 2020-11-30    51.984859
# 2020-12-31    48.362709
# 2021-01-31    56.826293
# 2021-02-28    50.360589
# 2021-03-31    50.796474
# 2021-04-30    29.681275
# 2021-05-31    26.035344
# 2021-06-30    10.668774
# Freq: M, Name: predicted_mean, dtype: float64

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(residuals/test_data.PM10)),3))
# Out:
# Mean Absolute Percent Error: 0.397

# %%
from sklearn.metrics import mean_squared_error, r2_score

# 평가 지표 계산
mse = mean_squared_error(test_data['PM10'], predictions)
rmse = np.sqrt(mse)

r2 = r2_score(test_data['PM10'], predictions)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse, rmse))
print("R2: {:3f}".format(r2))
# Out:
# MSE: 217.143, RMSE: 14.736
# R2: 0.003768

# %%
# 평가 지표 계산
mse2 = mean_squared_error(test_data['PM10'], air_forecast)
rmse2 = np.sqrt(mse2)

r22 = r2_score(test_data['PM10'], air_forecast)

print("MSE: {0:.3f}, RMSE: {1:.3f}".format(mse2, rmse2))
print("R2: {:3f}".format(r22))
# Out:
# MSE: 297.093, RMSE: 17.236
# R2: -0.363037
